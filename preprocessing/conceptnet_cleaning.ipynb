# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../data/conceptnet.csv", sep = "\t")

# %%
data.columns = ['edge-url', 'relation', 'head', 'tail', 'info']
data.columns

# %%
data.head()
