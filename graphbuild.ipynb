# %%
from graph import GraphBuilder

# %%
graphBuilder = GraphBuilder(device = "cuda:0")
# Out:
# ...
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]

# %%
f = graphBuilder.extract_triples_propositions("John and Janice are eating pizza.")
f
# Out:
# {('Janice', 'PerformsAction', 'eating'),
#  ('John', 'PerformsAction', 'eating'),
#  ('pizza', 'ReceivesAction', 'eating')}

# %%
h = graphBuilder.extract_triples_propositions("John and Janice are eating pizza.")
h
# Out:
# {('Janice', 'PerformsAction', 'eating'),
#  ('John', 'PerformsAction', 'eating'),
#  ('pizza', 'ReceivesAction', 'eating')}

# %%
g = graphBuilder.extract_triples_propositions("You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.")
g
# Out:
# [('sending', 'PerformsAction', 'requests'),
#  ('requests', 'ReceivesAction', 'sending'),
#  ('HF Hub', 'AtLocation', 'requests'),
#  ('HF_TOKEN', 'HasContext', 'HF_TOKEN'),
#  ('sending', 'HasModality', 'Obligation')]

# %%
p = graphBuilder.extract_triples_propositions("He and his friend played at the park, they played football and basketball.")
ma_liste = json.loads(p)
p
